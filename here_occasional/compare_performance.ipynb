# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams.update({'font.size': 16})

# %%
flow_20_true = pd.read_pickle('flow_20_true.pkl')
flow_20_pre = pd.read_pickle('flow_20.pkl')
flow_20_old = pd.read_pickle('flow_20_old.pkl')
# plt.plot(flow_20_true.T.sum(), label = 'AT-AU',color='g')
plt.plot(flow_20_true.T.sum(), label = 'AT',color='c')
plt.plot(flow_20_pre.T.sum(), label = 'TP-WF',color='b')
plt.plot(flow_20_old.T.sum(), label = 'TR-NF',color='m')
plt.xlabel('Time of day')
plt.ylabel('Traffic flow')
plt.legend()
plt.grid()

# %%
def smape(a, f):
    return 1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f))*100)

# %%
smape(flow_20_true, flow_20_pre).mean()
# Out:
# 29.831080546976864

# %%
smape(flow_20_true, flow_20_old).mean()
# Out:
# 56.53719213685715

# %%
import numpy as np
import scipy.stats as st

gfg_data =  smape(flow_20_true, flow_20_pre)

# create 95% confidence interval
st.t.interval(alpha=0.95, df=len(gfg_data)-1,
              loc=np.mean(gfg_data),
              scale=st.sem(gfg_data))
# Out:
# (26.14236550538207, 33.519795588571654)

# %%
gfg_data =  smape(flow_20_true, flow_20_old)

# create 95% confidence interval
st.t.interval(alpha=0.95, df=len(gfg_data)-1,
              loc=np.mean(gfg_data),
              scale=st.sem(gfg_data))
# Out:
# (52.285195803187804, 60.7891884705265)

# %%
vfn_true = [18.0,
 17.0,
 16.0,
 17.0,
 17.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 16.0,
 19.0,
 17.0,
 20.0,
 20.0,
 22.0]
vfn_pre = [20.0,
 21.0,
 20.0,
 20.0,
 20.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 28.0,
 21.0,
 22.0,
 22.0,
 23.0,
 24.0]
vfn_old = [19.0,
 18.0,
 16.0,
 18.0,
 15.0,
 21.0,
 30.0,
 30.0,
 30.0,
 30.0,
 27.0,
 24.0,
 23.0,
 22.0,
 30.0,
 30.0,
 30.0,
 25.0,
 19.0,
 19.0,
 19.0,
 19.0,
 19.0,
 20.0]
vfn_best = [20.0,
 19.0,
 20.0,
 18.0,
 20.0,
 27.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 30.0,
 22.0,
 20.0,
 20.0,
 21.0,
 24.0,
 21.0]
vfn_random = [29.0,
 30.0,
 30.0,
 29.0,
 28.0,
 27.0,
 29.0,
 28.0,
 28.0,
 29.0,
 28.0,
 30.0,
 24.0,
 28.0,
 29.0,
 29.0,
 26.0,
 28.0,
 29.0,
 30.0,
 29.0,
 30.0,
 29.0,
 28.0]
plt.ylabel('Active VFN number')
plt.xlabel('Time of day')
# plt.plot(vfn_true, label = 'AT-AU',color='g')
plt.plot(vfn_best, label = 'AT',color='c')
plt.plot(vfn_pre, label = 'TP-WF',color='b')
plt.plot(vfn_old, label = 'TP-NF',color='m')
plt.plot(vfn_random, label = 'RG',color='g')
plt.legend()
plt.grid()
