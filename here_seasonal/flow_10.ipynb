# %%
import json
import glob
import time
import pickle
import random
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xml.etree.ElementTree as et 
import warnings
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams.update({'font.size': 16})
plt.style.use('ggplot')

# %%
def iter_docs(author):
    author_attr = author.attrib
    for doc in author.iter('vehicle'):
        doc_dict = author_attr.copy()
        doc_dict.update(doc.attrib)
        #doc_dict['data'] = doc.text
        yield doc_dict

# %%
def iter_author(etree):
    for author in etree.iter('timestep'):
        for row in iter_docs(author):
            yield row

# %%
input_files = glob.glob("*.xml")[3:13]
input_files
# Out:
# ['here.output0.xml',
#  'here.output1.xml',
#  'here.output2.xml',
#  'here.output3.xml',
#  'here.output4.xml',
#  'here.output5.xml',
#  'here.output6.xml',
#  'here.output7.xml',
#  'here.output8.xml',
#  'here.output9.xml']

# %%
dates = pd.date_range(start="2022-02-28",end="2022-03-09")

clusters = pd.read_pickle('clusters_10.pkl')
dic = {str(clusters[i][j]):i for i in range(len(clusters)) for j in range(len(clusters[i]))}

df = pd.DataFrame()
for i in range(10):
    data = et.parse(input_files[i])
    df1 = pd.DataFrame(list(iter_author(data)))
    df1['time'] = df1['time'].astype('float')
    df1['time'] = df1['time'].astype('int')
    df1['seg0'] = df1['lane'].str.split('to').str[0]
    df1['seg1'] = df1['lane'].str.split(':n').str[1].str.split('_').str[0]
    df1['seg'] = df1['seg1'].fillna(df1['seg0'])
    df1['cl'] = df1['seg'].map(dic)
    df1['cl'] = df1['cl'].astype('int')
    df2 = pd.DataFrame()
    for time in df1['time'].unique():
        df2[time] = df1[df1['time']==time]['cl'].value_counts().reindex(list(range(0,len(clusters))),fill_value=0)
    df2 = df2.T
    df2.index = [str(dates[i])+" "+str(datetime.timedelta(seconds = index)) for index in df2.index]
    df2.index = pd.to_datetime(df2.index)
    if i== 0:
        df = df2
    else:
        df = pd.concat([df, df2])

df_re = df.resample('H').mean()

# %%
plt.rcParams.update({'font.size': 16})
plt.rcParams["figure.figsize"] = (20,3)
df_re.plot(legend=None)
plt.grid()
plt.ylabel('Traffic flow')
plt.xlabel('Time')
# xlim = np.arange(0, 60* 60 *24, 60*60*4)
# plt.xticks(xlim, [str(n).zfill(2) + ':00' for n in np.arange(0, 24, 4)])
# Out:
# Text(0.5, 0, 'Time')

# %%
# Define the d and q parameters to take any value between 0 and 1
q = d = range(0, 2)
# Define the p parameters to take any value between 0 and 3
p = range(3, 4)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))
# pdq = [(3,0,0)]

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 24) for x in list(itertools.product(p, d, q))]
# seasonal_pdq = [(3,1,0,24)]

# print('Examples of parameter combinations for Seasonal ARIMA...')
# print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
# print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
# print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))

# %%
train_set = df_re['2022-02-28':'2022-03-08']
test_set = df_re['2022-03-09':'2022-03-09']

# %%
def SARIMA(train_data, test_data):
    # Train the model
    warnings.filterwarnings("ignore") # specify to ignore warning messages
    AIC = []
    SARIMAX_model = []
    for param in pdq:
        for param_seasonal in seasonal_pdq:
            try:
                mod = sm.tsa.statespace.SARIMAX(train_data,
                                                order=param,
                                                seasonal_order=param_seasonal,
                                                enforce_stationarity=False,
                                                enforce_invertibility=False)

                results = mod.fit()

                print('SARIMAX{}x{} - AIC:{}'.format(param, param_seasonal, results.aic), end='\r')
                AIC.append(results.aic)
                SARIMAX_model.append([param, param_seasonal])
            except:
                continue
    parameter = [min(AIC), SARIMAX_model[AIC.index(min(AIC))][0],SARIMAX_model[AIC.index(min(AIC))][1]]
    print('The smallest AIC is {} for model SARIMAX{}x{}'.format(min(AIC), SARIMAX_model[AIC.index(min(AIC))][0],SARIMAX_model[AIC.index(min(AIC))][1]))

    # Fit the model
    mod = sm.tsa.statespace.SARIMAX(train_data,
                                    order=SARIMAX_model[AIC.index(min(AIC))][0],
                                    seasonal_order=SARIMAX_model[AIC.index(min(AIC))][1],
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)
    results = mod.fit()

    # Prediction
    pred2 = results.get_forecast('2022-03-09 23:00:00')
    pred2_ci = pred2.conf_int()
    prediction = pred2.predicted_mean['2022-03-09 00:00:00':'2022-03-09 23:00:00'].values

    # Mean Absolute Percentage Error
    truth = test_data.values
    # MAPE = np.mean(np.abs((truth - prediction) / truth)) * 100
    MAE = np.mean(np.abs(truth - prediction))
    print('The Mean Absolute Percentage Error for the forecast of 2022-03-09 is {:.2f}'.format(MAE))
    return parameter, prediction, MAE

# %%
predictions = []
MAEs = []
parameters = []
for cl in range(len(clusters)):
    train_data = train_set[cl]
    test_data = test_set[cl]
    parameter, prediction, MAE = SARIMA(train_data, test_data)
    parameters.append(parameter)
    predictions.append(prediction)
    MAEs.append(MAE)
# Out:
# The smallest AIC is 188.99606714774944 for model SARIMAX(3, 0, 0)x(3, 1, 1, 24)
# The Mean Absolute Percentage Error for the forecast of 2022-03-09 is 0.39
# The smallest AIC is 338.5365393790245 for model SARIMAX(3, 1, 1)x(3, 1, 1, 24)
# The Mean Absolute Percentage Error for the forecast of 2022-03-09 is 0.80
# The smallest AIC is 277.4220252904411 for model SARIMAX(3, 0, 0)x(3, 1, 1, 24)
# The Mean Absolute Percentage Error for the forecast of 2022-03-09 is 0.38
# The smallest AIC is 64.66646680186224 for model SARIMAX(3, 0, 0)x(3, 1, 1, 24)
# The Mean Absolute Percentage Error for the forecast of 2022-03-09 is 0.22
# The smallest AIC is 217.53036573893326 for model SARIMAX(3, 0, 1)x(3, 1, 1, 24)
# The Mean Absolute Percentage Error for the forecast of 2022-03-09 is 0.57
# The smallest AIC is 285.54803368468976 for model SARIMAX(3, 0, 0)x(3, 1, 1, 24)
# The Mean Absolute Percentage Error for the forecast of 2022-03-09 is 0.60
# The smallest AIC is 244.16224430062243 for model SARIMAX(3, 0, 0)x(3, 1, 1, 24)
# The Mean Absolute Percentage Error for the forecast of 2022-03-09 is 0.26
# The smallest AIC is 248.98186830161242 for model SARIMAX(3, 0, 0)x(3, 1, 1, 24)
# The Mean Absolute Percentage Error for the forecast of 2022-03-09 is 0.50
# The smallest AIC is 166.66480272449832 for model SARIMAX(3, 0, 0)x(3, 1, 1, 24)
# The Mean Absolute Percentage Error for the forecast of 2022-03-09 is 0.27
# The smallest AIC is 314.84905462600557 for model SARIMAX(3, 0, 0)x(3, 1, 1, 24)
# The Mean Absolute Percentage Error for the forecast of 2022-03-09 is 0.76

# %%
sum(MAEs)/len(MAEs)
# Out:
# 0.47585061375644766

# %%
flow_cl = pd.DataFrame(predictions).T.round(0).astype('int')
flow_cl.to_pickle('flow_%i.pkl'%len(clusters))

# %%
df3 = pd.DataFrame(df_re['2022-03-09':'2022-03-09'].T.sum())
df3[1] = pd.DataFrame(predictions).round(0).astype('int').sum().tolist()
plt.plot(df3)
# Out:
# [<matplotlib.lines.Line2D at 0x1f425d61348>,
#  <matplotlib.lines.Line2D at 0x1f426b24108>]

# %%
df3['error'] = abs(df3[0]-df3[1])
df3['error'].tolist()
# Out:
# [0.3636363636363642,
#  0.5,
#  0.5833333333333321,
#  1.333333333333333,
#  2.083333333333332,
#  4.583333333333336,
#  0.5833333333333357,
#  4.916666666666657,
#  5.083333333333343,
#  2.0,
#  5.5,
#  1.8333333333333357,
#  3.1666666666666643,
#  0.4166666666666643,
#  2.916666666666657,
#  4.583333333333343,
#  0.8333333333333428,
#  3.75,
#  2.083333333333334,
#  1.333333333333333,
#  1.7763568394002505e-15,
#  1.25,
#  1.583333333333334,
#  3.583333333333332]

# %%
df3['error'].mean()
# Out:
# 2.285984848484849

# %%
df3['error'].std()
# Out:
# 1.718130246371975
